# %% [markdown]
# # I will be using the FBI Gun Dataset

# %% [markdown]
# In this analysis I am going to investigate whether or not the population of a state is correlated with the number of permit checks in that state for 2016

# %% [markdown]
# To start off I am going to import the relevant libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np

# %% [markdown]
# Now I am going to import my data

# %%
gun_df = pd.read_csv("C:/Users/khali/Downloads/Copy of gun_data.csv")
gun_df
# Out:
#          month          state   permit  permit_recheck  handgun  long_gun  \
# 0      2017-09        Alabama  16717.0             0.0   5734.0    6320.0
# 1      2017-09         Alaska    209.0             2.0   2320.0    2930.0
# 2      2017-09        Arizona   5069.0           382.0  11063.0    7946.0
# 3      2017-09       Arkansas   2935.0           632.0   4347.0    6063.0
# 4      2017-09     California  57839.0             0.0  37165.0   24581.0
# ...        ...            ...      ...             ...      ...       ...
# 12480  1998-11       Virginia      0.0             NaN     14.0       2.0
# 12481  1998-11     Washington      1.0             NaN     65.0     286.0
# 12482  1998-11  West Virginia      3.0             NaN    149.0     251.0
# 12483  1998-11      Wisconsin      0.0             NaN     25.0     214.0
# 12484  1998-11        Wyoming      8.0             NaN     45.0      49.0
#
#         other  multiple  admin  prepawn_handgun  ...  returned_other  \
# ...

# %% [markdown]
# I am now going to check for duplicated values and delete them if they exist

# %%
sum(gun_df.duplicated())
# Out:
# 0

# %% [markdown]
# Now I am going to import the census data

# %%
census_df = pd.read_csv("C:/Users/khali/Downloads/U.S. Census Data - Copy.csv")
census_df
# Out:
#                                                  Fact  \
# 0        Population estimates, July 1, 2016,  (V2016)
# 1   Population estimates base, April 1, 2010,  (V2...
# 2   Population, percent change - April 1, 2010 (es...
# 3                   Population, Census, April 1, 2010
# 4   Persons under 5 years, percent, July 1, 2016, ...
# ..                                                ...
# 80                                                 FN
# 81                                                NaN
# 82                                                  S
# 83                                                  X
# 84                                                  Z
#
#                                             Fact Note    Alabama   Alaska  \
# 0                                                 NaN  4,863,300  741,894
# 1                                                 NaN  4,780,131  710,249
# 2                                                 NaN      1.70%    4.50%
# ...

# %%
sum(census_df.duplicated())
# Out:
# 0

# %% [markdown]
# I see that the file is in wide format so I am going to change it to long format

# %%
census_long = census_df.transpose()

census_long
# Out:
#                                                           0   \
# State
# index                                                      0
# Fact            Population estimates, July 1, 2016,  (V2016)
# Fact Note                                                NaN
# Alabama                                            4,863,300
# Alaska                                               741,894
# Arizona                                            6,931,071
# Arkansas                                           2,988,248
# California                                        39,250,017
# Colorado                                           5,540,545
# Connecticut                                        3,576,452
# Delaware                                             952,065
# Florida                                           20,612,439
# Georgia                                           10,310,371
# Hawaii                                             1,428,557
# ...

# %%
census_long.drop('Fact Note', inplace = True)
census_long
# Out:
#                                                           0   \
# State
# index                                                      0
# Fact            Population estimates, July 1, 2016,  (V2016)
# Alabama                                            4,863,300
# Alaska                                               741,894
# Arizona                                            6,931,071
# Arkansas                                           2,988,248
# California                                        39,250,017
# Colorado                                           5,540,545
# Connecticut                                        3,576,452
# Delaware                                             952,065
# Florida                                           20,612,439
# Georgia                                           10,310,371
# Hawaii                                             1,428,557
# Idaho                                              1,683,140
# ...

# %%
# Set the first row as header
census_long.columns = census_long.iloc[0]

# Drop the first row
census_long = census_long.drop(census_long.index[0])
census_long
# Out:
# index                                                     0   \
# State
# Fact            Population estimates, July 1, 2016,  (V2016)
# Alabama                                            4,863,300
# Alaska                                               741,894
# Arizona                                            6,931,071
# Arkansas                                           2,988,248
# California                                        39,250,017
# Colorado                                           5,540,545
# Connecticut                                        3,576,452
# Delaware                                             952,065
# Florida                                           20,612,439
# Georgia                                           10,310,371
# Hawaii                                             1,428,557
# Idaho                                              1,683,140
# Illinois                                          12,801,539
# ...

# %%
# Assuming census_long is your DataFrame and 'Fact' is the row you want to move to a new column
census_long.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14516\2363637968.py in ?()
#       1 # Assuming census_long is your DataFrame and 'Fact' is the row you want to move to a new column
# ----> 2 census_long.reset_index(inplace=True)
#       3 census_long
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6216                     level_values = algorithms.take(
#    6217                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6218                     )
#    6219
# -> 6220                 new_obj.insert(
#    6221                     0,
#    6222                     name,
#    6223                     level_values,
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
# ...

# %%
census_long
# Out:
# Fact  level_0  index           State  \
# 0           0      0         Alabama
# 1           1      1          Alaska
# 2           2      2         Arizona
# 3           3      3        Arkansas
# 4           4      4      California
# 5           5      5        Colorado
# 6           6      6     Connecticut
# 7           7      7        Delaware
# 8           8      8         Florida
# 9           9      9         Georgia
# 10         10     10          Hawaii
# 11         11     11           Idaho
# 12         12     12        Illinois
# 13         13     13         Indiana
# 14         14     14            Iowa
# 15         15     15          Kansas
# 16         16     16        Kentucky
# 17         17     17       Louisiana
# 18         18     18           Maine
# 19         19     19        Maryland
# 20         20     20   Massachusetts
# 21         21     21        Michigan
# 22         22     22       Minnesota
# 23         23     23     Mississippi
# ...

# %%
census_long.drop('level_0', axis=1, inplace =True)
census_long
# Out:
# Fact  index           State Population estimates, July 1, 2016,  (V2016)  \
# 0         0         Alabama                                    4,863,300
# 1         1          Alaska                                      741,894
# 2         2         Arizona                                    6,931,071
# 3         3        Arkansas                                    2,988,248
# 4         4      California                                   39,250,017
# 5         5        Colorado                                    5,540,545
# 6         6     Connecticut                                    3,576,452
# 7         7        Delaware                                      952,065
# 8         8         Florida                                   20,612,439
# 9         9         Georgia                                   10,310,371
# 10       10          Hawaii                                    1,428,557
# 11       11           Idaho                                    1,683,140
# ...

# %%
census_2016 = census_long[['State', 'Population estimates, July 1, 2016,  (V2016)']]
census_2016
# Out:
# Fact           State Population estimates, July 1, 2016,  (V2016)
# 0            Alabama                                    4,863,300
# 1             Alaska                                      741,894
# 2            Arizona                                    6,931,071
# 3           Arkansas                                    2,988,248
# 4         California                                   39,250,017
# 5           Colorado                                    5,540,545
# 6        Connecticut                                    3,576,452
# 7           Delaware                                      952,065
# 8            Florida                                   20,612,439
# 9            Georgia                                   10,310,371
# 10            Hawaii                                    1,428,557
# 11             Idaho                                    1,683,140
# 12          Illinois                                   12,801,539
# ...

# %%
census_2016.loc[:, 'Population estimates, July 1, 2016,  (V2016)'] = census_2016['Population estimates, July 1, 2016,  (V2016)'].str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 census_2016.loc[:, 'Population estimates, July 1, 2016,  (V2016)'] = census_2016['Population estimates, July 1, 2016,  (V2016)'].str.replace(',', '').astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
census_2016
# Out:
# Fact           State  Population estimates, July 1, 2016,  (V2016)
# 0            Alabama                                       4863300
# 1             Alaska                                        741894
# 2            Arizona                                       6931071
# 3           Arkansas                                       2988248
# 4         California                                      39250017
# 5           Colorado                                       5540545
# 6        Connecticut                                       3576452
# 7           Delaware                                        952065
# 8            Florida                                      20612439
# 9            Georgia                                      10310371
# 10            Hawaii                                       1428557
# 11             Idaho                                       1683140
# 12          Illinois                                      12801539
# ...

# %% [markdown]
# Now I am going to get the 2016 data from the FBI gun data set

# %%
gun_df
# Out:
#          month          state   permit  permit_recheck  handgun  long_gun  \
# 0      2017-09        Alabama  16717.0             0.0   5734.0    6320.0
# 1      2017-09         Alaska    209.0             2.0   2320.0    2930.0
# 2      2017-09        Arizona   5069.0           382.0  11063.0    7946.0
# 3      2017-09       Arkansas   2935.0           632.0   4347.0    6063.0
# 4      2017-09     California  57839.0             0.0  37165.0   24581.0
# ...        ...            ...      ...             ...      ...       ...
# 12480  1998-11       Virginia      0.0             NaN     14.0       2.0
# 12481  1998-11     Washington      1.0             NaN     65.0     286.0
# 12482  1998-11  West Virginia      3.0             NaN    149.0     251.0
# 12483  1998-11      Wisconsin      0.0             NaN     25.0     214.0
# 12484  1998-11        Wyoming      8.0             NaN     45.0      49.0
#
#         other  multiple  admin  prepawn_handgun  ...  returned_other  \
# ...

# %%
gun_df_2016 = gun_df[gun_df['month'].str.startswith('2016')]
gun_df_2016
# Out:
#         month          state   permit  permit_recheck  handgun  long_gun  \
# 495   2016-12        Alabama  26996.0             0.0  13733.0   17519.0
# 496   2016-12         Alaska    254.0             0.0   4087.0    3698.0
# 497   2016-12        Arizona   8900.0           121.0  18024.0   13785.0
# 498   2016-12       Arkansas   3294.0           692.0   9192.0   13433.0
# 499   2016-12     California  61808.0             0.0  63649.0   93224.0
# ...       ...            ...      ...             ...      ...       ...
# 1150  2016-01       Virginia    524.0             NaN  27033.0   15699.0
# 1151  2016-01     Washington  19688.0             NaN  20427.0   11355.0
# 1152  2016-01  West Virginia   3378.0             NaN   7419.0    5505.0
# 1153  2016-01      Wisconsin   9496.0             NaN  17969.0   10756.0
# 1154  2016-01        Wyoming    959.0             NaN   2181.0    1983.0
#
#         other  multiple  admin  prepawn_handgun  ...  returned_other  \
# ...

# %%
gun_df_2016_grouped = gun_df_2016.groupby('state')['permit'].sum().reset_index()
gun_df_2016_grouped
# Out:
#                    state     permit
# 0                Alabama   291039.0
# 1                 Alaska     3121.0
# 2                Arizona    87771.0
# 3               Arkansas    55456.0
# 4             California  1036981.0
# 5               Colorado    85087.0
# 6            Connecticut   148949.0
# 7               Delaware     8440.0
# 8   District of Columbia      144.0
# 9                Florida   337086.0
# 10               Georgia   233115.0
# 11                  Guam        0.0
# 12                Hawaii    16627.0
# 13                 Idaho    38086.0
# 14              Illinois   962930.0
# 15               Indiana   946912.0
# 16                  Iowa   161841.0
# 17                Kansas    19402.0
# 18              Kentucky  3372613.0
# 19             Louisiana    35141.0
# 20                 Maine     6986.0
# 21       Mariana Islands        0.0
# 22              Maryland    36025.0
# 23         Massachusetts    97516.0
# 24              Michigan   251162.0
# ...

# %%
final_df = pd.merge(gun_df_2016_grouped, census_2016, left_on='state', right_on='State')

# %%
final_df
# Out:
#              state     permit           State  \
# 0          Alabama   291039.0         Alabama
# 1           Alaska     3121.0          Alaska
# 2          Arizona    87771.0         Arizona
# 3         Arkansas    55456.0        Arkansas
# 4       California  1036981.0      California
# 5         Colorado    85087.0        Colorado
# 6      Connecticut   148949.0     Connecticut
# 7         Delaware     8440.0        Delaware
# 8          Florida   337086.0         Florida
# 9          Georgia   233115.0         Georgia
# 10          Hawaii    16627.0          Hawaii
# 11           Idaho    38086.0           Idaho
# 12        Illinois   962930.0        Illinois
# 13         Indiana   946912.0         Indiana
# 14            Iowa   161841.0            Iowa
# 15          Kansas    19402.0          Kansas
# 16        Kentucky  3372613.0        Kentucky
# 17       Louisiana    35141.0       Louisiana
# 18           Maine     6986.0           Maine
# ...

# %%
final_df.drop('State', axis=1, inplace=True)
final_df
# Out:
#     index           state     permit  \
# 0       0         Alabama   291039.0
# 1       1          Alaska     3121.0
# 2       2         Arizona    87771.0
# 3       3        Arkansas    55456.0
# 4       4      California  1036981.0
# 5       5        Colorado    85087.0
# 6       6     Connecticut   148949.0
# 7       7        Delaware     8440.0
# 8       8         Florida   337086.0
# 9       9         Georgia   233115.0
# 10     10          Hawaii    16627.0
# 11     11           Idaho    38086.0
# 12     12        Illinois   962930.0
# 13     13         Indiana   946912.0
# 14     14            Iowa   161841.0
# 15     15          Kansas    19402.0
# 16     16        Kentucky  3372613.0
# 17     17       Louisiana    35141.0
# 18     18           Maine     6986.0
# 19     19        Maryland    36025.0
# 20     20   Massachusetts    97516.0
# 21     21        Michigan   251162.0
# 22     22       Minnesota   350315.0
# 23     23     Mississippi    22564.0
# ...

# %%
final_df.drop('index', axis=1, inplace=True)

# %%
final_df
# Out:
#              state     permit  Population
# 0          Alabama   291039.0     4863300
# 1           Alaska     3121.0      741894
# 2          Arizona    87771.0     6931071
# 3         Arkansas    55456.0     2988248
# 4       California  1036981.0    39250017
# 5         Colorado    85087.0     5540545
# 6      Connecticut   148949.0     3576452
# 7         Delaware     8440.0      952065
# 8          Florida   337086.0    20612439
# 9          Georgia   233115.0    10310371
# 10          Hawaii    16627.0     1428557
# 11           Idaho    38086.0     1683140
# 12        Illinois   962930.0    12801539
# 13         Indiana   946912.0     6633053
# 14            Iowa   161841.0     3134693
# 15          Kansas    19402.0     2907289
# 16        Kentucky  3372613.0     4436974
# 17       Louisiana    35141.0     4681666
# 18           Maine     6986.0     1331479
# 19        Maryland    36025.0     6016447
# 20   Massachusetts    97516.0     6811779
# ...

# %%
final_df.rename(columns={'Population estimates, July 1, 2016,  (V2016)': 'Population'}, inplace=True)

# %% [markdown]
# I am now going to create a bar chart with the population of the states

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.bar(final_df['state'], final_df['Population'])

fmt = '{x:,.0f}M'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
ax.set_xlabel('State')
ax.set_ylabel('Population')
ax.set_title('Population of States in 2016')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Now I want to analyze the number of permits issued per state. In order to do this I will have to create a new dataframe with the aggregated 2016 year and permit values for each state.

# %%
permit_checks_by_state = final_df.groupby('State')['permit'].sum()

permit_checks_by_state
# Out:
# State
# Alabama            291039.0
# Alaska               3121.0
# Arizona             87771.0
# Arkansas            55456.0
# California        1036981.0
# Colorado            85087.0
# Connecticut        148949.0
# Delaware             8440.0
# Florida            337086.0
# Georgia            233115.0
# Hawaii              16627.0
# Idaho               38086.0
# Illinois           962930.0
# Indiana            946912.0
# Iowa               161841.0
# Kansas              19402.0
# Kentucky          3372613.0
# Louisiana           35141.0
# Maine                6986.0
# Maryland            36025.0
# Massachusetts       97516.0
# Michigan           251162.0
# Minnesota          350315.0
# Mississippi         22564.0
# Missouri            90972.0
# Montana             20512.0
# Nebraska            58386.0
# Nevada              30950.0
# New Hampshire       48347.0
# New Jersey              0.0
# New Mexico          14149.0
# New York            49646.0
# North Carolina     345364.0
# ...

# %%
fig, ax = plt.subplots()

permit_checks_by_state.plot(kind='bar', figsize=(12, 6))

# Format y-axis labels to display in millions
fmt = '{x:,.0f}M'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

plt.xlabel('State')
plt.ylabel('Number of Permit Checks')
plt.title('Number of Permit Checks per State in 2016')
# Out:
# Text(0.5, 1.0, 'Number of Permit Checks per State in 2016')

# %% [markdown]
# Now I am going to create a scatter plot to illustrate the relationship between population size and the number of permit checks

# %%
# Merge the dataframes on 'State'
scatterplot_df = pd.merge(population_df, permit_checks_by_state, on='State')
scatterplot_df = scatterplot_df.reset_index()

# %%
scatterplot_df
# Out:
#              State                                          Fact  Population  \
# 0          Alabama  Population estimates, July 1, 2016,  (V2016)     4863300
# 1           Alaska  Population estimates, July 1, 2016,  (V2016)      741894
# 2          Arizona  Population estimates, July 1, 2016,  (V2016)     6931071
# 3         Arkansas  Population estimates, July 1, 2016,  (V2016)     2988248
# 4       California  Population estimates, July 1, 2016,  (V2016)    39250017
# 5         Colorado  Population estimates, July 1, 2016,  (V2016)     5540545
# 6      Connecticut  Population estimates, July 1, 2016,  (V2016)     3576452
# 7         Delaware  Population estimates, July 1, 2016,  (V2016)      952065
# 8          Florida  Population estimates, July 1, 2016,  (V2016)    20612439
# 9          Georgia  Population estimates, July 1, 2016,  (V2016)    10310371
# 10          Hawaii  Population estimates, July 1, 2016,  (V2016)     1428557
# ...

# %%
# Create a scatterplot
fig, ax = plt.subplots(figsize=(10,6))

# Create a color map
colors = plt.get_cmap('viridis', lut=len(scatterplot_df['State'].unique()))

# Create a scatter plot with color coding for each state
scatter = ax.scatter(scatterplot_df['Population'], scatterplot_df['permit_y'], c=scatterplot_df['State'].astype('category').cat.codes, cmap=colors)

# Format x-axis to represent millions
ax.xaxis.set_major_# Create a scatterplot
fig, ax = plt.subplots(figsize=(10,6))

# Create a color map
cmap = plt.get_cmap('viridis', lut=len(scatterplot_df['State'].unique()))

# Create a scatter plot with color coding for each state
scatter = ax.scatter(scatterplot_df['Population'], scatterplot_df['permit_y'], c=scatterplot_df['State'].astype('category').cat.codes, cmap=cmap)

# Format x-axis to represent millions
ax.xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}M'))

# Make x-axis labels vertical
plt.xticks(rotation='vertical')

# Add a color bar as legend
cbar = plt.colorbar(scatter, ticks=range(len(scatterplot_df['State'].unique())), pad=0.01)
cbar.set_label('States')
cbar.set_ticks(np.arange(len(scatterplot_df['State'].unique())) + 0.5)
cbar.set_ticklabels(scatterplot_df['State'].unique())

plt.xlabel('Population (in millions)')
plt.ylabel('Permit Checks')
plt.title('Population vs Permit Checks by State')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[183], line 11
#       8 scatter = ax.scatter(scatterplot_df['Population'], scatterplot_df['permit_y'], c=scatterplot_df['State'].astype('category').cat.codes, cmap=colors)
#      10 # Format x-axis to represent millions
# ---> 11 ax.xaxis.set_major_# Create a scatterplot
#      12 fig, ax = plt.subplots(figsize=(10,6))
#      14 # Create a color map
#
# AttributeError: 'XAxis' object has no attribute 'set_major_'
